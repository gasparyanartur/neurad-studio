# %%
# %load_ext autoreload
# %autoreload 2
# %cd ~/dev/neurad-studio
# Out:
# /home/gasparyanartur/dev/neurad-studio

# %%
from nerfstudio.generative.dynamic_dataset import DynamicDataset, NeuRADInfoGetter, RGBDataGetter
from nerfstudio.generative.utils import show_img
from pathlib import Path


dataset = DynamicDataset.from_config({
    "dataset": "neurad",
    "path": "data/neurad_outputs/",
    "data_getters": {
        "rgb": {
            "camera": "front_left_camera",
            "split": "test",
        },

        "gt-rgb": {
            "data_type": "rgb",
            "camera": "front_left_camera",
            "split": "test"
        },

        "meta": {}
    },
    "data_tree": {
        "neurad_outputs": {
            "001": "::10"
        }
    }
})

pred = dataset[3]["rgb"]
gt = dataset[3]["gt-rgb"]
print(dataset[3]["meta"])
show_img((pred, gt))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [2], line 6
#       2 from nerfstudio.generative.utils import show_img
#       3 from pathlib import Path
# ----> 6 dataset = DynamicDataset.from_config({
#       7     "dataset": "neurad",
#       8     "path": "data/neurad_outputs/",
#       9     "data_getters": {
#      10         "rgb": {
#      11             "camera": "front_left_camera",
#      12             "split": "test",
#      13         },
#      14
#      15         "gt-rgb": {
#      16             "data_type": "rgb",
#      17             "camera": "front_left_camera",
#      18             "split": "test"
#      19         },
#      20
#      21         "meta": {}
#      22     },
#      23     "data_tree": {
#      24         "neurad_outputs": {
#      25             "001": "::10"
#      26         }
#      27     }
#      28 })
#      30 pred = dataset[3]["rgb"]
#      31 gt = dataset[3]["gt-rgb"]
#
# File ~/dev/neurad-studio/nerfstudio/generative/dynamic_dataset.py:931, in DynamicDataset.from_config(cls, dataset_config, **kwargs)
#     927     data_getter = data_getter_factory(info_getter, spec)
#     929     data_getters[spec_name] = data_getter
# --> 931 return DynamicDataset(
#     932     dataset_path, data_tree, info_getter, data_getters, **kwargs
#     933 )
#
# File ~/dev/neurad-studio/nerfstudio/generative/dynamic_dataset.py:840, in DynamicDataset.__init__(self, dataset_path, data_tree, info_getter, data_getters, data_transforms, preprocess_func)
#     831 def __init__(
#     832     self,
#     833     dataset_path: Path,
#    (...)
#     838     preprocess_func=None,
#     839 ):
# --> 840     self.sample_infos: list[SampleInfo] = info_getter.parse_tree(
#     841         dataset_path, data_tree
#     842     )
#     843     self.info_getter = info_getter
#     844     self.data_getters = data_getters
#
# File ~/dev/neurad-studio/nerfstudio/generative/dynamic_dataset.py:329, in InfoGetter.parse_tree(self, dataset_path, data_tree)
#     324 def parse_tree(
#     325     self, dataset_path: Path, data_tree: Dict[str, Any]
#     326 ) -> list[SampleInfo]:
#     327     samples = []
# --> 329     existing_scenes = set(path.stem for path in dataset_path.iterdir())
#     331     for dataset_name, dataset_dict in data_tree.items():
#     332         for scene_name, sample_list in dataset_dict.items():
#
# File ~/dev/neurad-studio/nerfstudio/generative/dynamic_dataset.py:329, in <genexpr>(.0)
#     324 def parse_tree(
#     325     self, dataset_path: Path, data_tree: Dict[str, Any]
#     326 ) -> list[SampleInfo]:
#     327     samples = []
# --> 329     existing_scenes = set(path.stem for path in dataset_path.iterdir())
#     331     for dataset_name, dataset_dict in data_tree.items():
#     332         for scene_name, sample_list in dataset_dict.items():
#
# File /usr/lib/python3.10/pathlib.py:1017, in Path.iterdir(self)
#    1013 def iterdir(self):
#    1014     """Iterate over the files in this directory.  Does not yield any
#    1015     result for the special paths '.' and '..'.
#    1016     """
# -> 1017     for name in self._accessor.listdir(self):
#    1018         if name in {'.', '..'}:
#    1019             # Yielding a path object for these makes little sense
#    1020             continue
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/neurad_outputs'

# %%
dataset = DynamicDataset.from_config({
    "dataset": "pandaset",
    "path": "data/pandaset/",
    "data_getters": {
        "rgb": {
            "camera": "front_left_camera",
        },

        "ref-rgb": {
            "camera": "front_left_camera",
        },

        "meta": {},
        "cn_ray_6_front_left_camera": {}
    },
    "data_tree": {
        "neurad_outputs": {
            "001": "::"
        }
    }
})

import torchvision.transforms.v2 as tvtf
batch = dataset[0]
pred = tvtf.Compose((tvtf.CenterCrop((1024, 1024)), tvtf.Resize((512, 512), antialias=True)))(batch["rgb"])
ref_rgb = batch["ref-rgb"]["rgb"]
ref_gt = batch["ref-rgb"]["gt"]
print(batch["meta"])
show_img((pred))
show_img((ref_rgb, ref_gt))
# Out:
# {'dataset': 'neurad_outputs', 'scene': '001', 'sample': '00'}

# %%
data/reference_neurad/001/front_left_camera/0m/train/rgb/00.jpg
data/reference_neurad/001/front_left_camera/0m/train/rgb/15.jpg
